# %%
from deepface import DeepFace as dfc
from deepface import DeepFace
from retinaface import RetinaFace
import matplotlib.pyplot as plt
import cv2
import sys
# from moviepy.editor import VideoFileClip
from moviepy.video.io.VideoFileClip import VideoFileClip

# %%
# Importing Needed Libraries

import cv2
import time
import math
import os
import numpy as np


# Setting Up Time
start = time.time()
 
# Opens the Video file
cap= cv2.VideoCapture('Daniel2.mp4') # Video of Daniel Radcliff
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
i=50
recog = 0
start= time.time()
fps = cap.get(cv2.CAP_PROP_FPS)

img1 = "pp.jpg"
img2 = ""


while(cap.isOpened()):
    
# Extracting Frames
    cap.set(1, i)
    ret, frame = cap.read()
    if ret == False:
        break
        
# Keep checking if the concerned candidate is in the video.
        
    cv2.imwrite('kang.jpg',frame)
    recognition = dfc.find(img_path = 'kang.jpg', db_path = 'facial_db', enforce_detection = False)
    
    # db_path is the path to the folder which contains the photos of Daniel Radcliff
        
    if(recognition.shape[0] == 0 or recognition['VGG-Face_cosine'][0] > 2):
        #print(recognition)
        print()
        
        
        
    if(recognition.shape[0] == 0 or recognition['VGG-Face_cosine'][0] < 2 or len(faces) > 1):
        recog += 1
        img2 = 'Stored Frames\\kang'+str(i)+'.jpg'
        cv2.imwrite('Stored Frames\\kang'+str(i)+'.jpg',frame)
            
        verification = dfc.verify(img1_path = img1, img2_path = img2, enforce_detection = False)
        
        if(verification['verified']):
            os.remove(img1)

            
## Storing the frame in which the concerned candidate is not detected.
            
        img1 = 'Stored Frames\\kang'+str(i)+'.jpg'

# Keep Checking the number of person's infront of the camera.

    image = cv2.imread('kang.jpg')
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


    faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=3,
    minSize=(30, 30))


    print("Number of faces", len(faces))
    os.remove('kang.jpg')
    i = i + int(fps)

    recognition = np.nan

    
    
# This code will help you to check if the candidates behaviour was proper and Has the test gone smoothly.
    
if(recog > 3):
    print("Candidate either had not attended the Test Properly. Or their might be some technical Issue")
    

    
cap.release()
cv2.destroyAllWindows()
print(start - time.time())
# Out:
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8286364078521729  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.935704231262207  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9310340881347656  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.904759407043457  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8828399181365967  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9295873641967773  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.1199696063995361  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9420905113220215  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9349229335784912  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.4599237442016602  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.546689510345459  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.714949607849121  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.023500919342041  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9008378982543945  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9354352951049805  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9246416091918945  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0527729988098145  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.106614112854004  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9044780731201172  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0130698680877686  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8645727634429932  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8814737796783447  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8724110126495361  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0016875267028809  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9394922256469727  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8451313972473145  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9303719997406006  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9685440063476562  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.947486400604248  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.956798791885376  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0254411697387695  seconds
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0197856426239014  seconds
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.022397756576538  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.847597599029541  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8878350257873535  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9278388023376465  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8887100219726562  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9172699451446533  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8739144802093506  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9553005695343018  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.896045446395874  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8914337158203125  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8799433708190918  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.897803544998169  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9137964248657227  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0120141506195068  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8436253070831299  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9406421184539795  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9743897914886475  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9981768131256104  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9466474056243896  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.986748218536377  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.990039587020874  seconds
#
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0049057006835938  seconds
#
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8750669956207275  seconds
#
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8768999576568604  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9591701030731201  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9376182556152344  seconds
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9230597019195557  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.990382194519043  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9115064144134521  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0215158462524414  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.068054437637329  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9450972080230713  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9334163665771484  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8925895690917969  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8928024768829346  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0181374549865723  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9728689193725586  seconds
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.00154709815979  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.041313648223877  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0363221168518066  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9999315738677979  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8749420642852783  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9045968055725098  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8609218597412109  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8432619571685791  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9417805671691895  seconds
#
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8593213558197021  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.838759183883667  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.173001766204834  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.2657933235168457  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9334650039672852  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.2792701721191406  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9933090209960938  seconds
# Number of faces 4
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.045877456665039  seconds
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.080683708190918  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9465992450714111  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8736436367034912  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9401218891143799  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9179999828338623  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8856165409088135  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9466617107391357  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9788782596588135  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9406771659851074  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9419057369232178  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.956653356552124  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.845181941986084  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8487684726715088  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.646064043045044  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0134546756744385  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.3749337196350098  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0421717166900635  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.1227197647094727  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0181405544281006  seconds
# Number of faces 3
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0010881423950195  seconds
#
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9826993942260742  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.227900743484497  seconds
#
# Number of faces 9
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.2555503845214844  seconds
#
# Number of faces 9
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.8972721099853516  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9362499713897705  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9043512344360352  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9305210113525391  seconds
# Number of faces 2
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0562663078308105  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9034767150878906  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0361573696136475  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.9033823013305664  seconds
# Number of faces 0
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.0348608493804932  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  0.900670051574707  seconds
# Number of faces 1
# WARNING: Representations for images in  facial_db  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_vgg_face.pkl
# find function lasts  1.1920604705810547  seconds
